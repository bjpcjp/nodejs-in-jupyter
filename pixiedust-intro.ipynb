# %% [markdown]
# # Node.js in Jupyter Notebooks
#
# ![diagram](pixiedust.png)
#
# * Using the [pixiedust_node](https://github.com/ibm-watson-data-lab/pixiedust_node) Jupyter add-on
# * Inspiration:
#     - [Part I (Intro)](https://medium.com/ibm-watson-data-lab/nodebooks-node-js-data-science-notebooks-aa140bea21ba)
#     - [Part II (Sharing data between NodeJS & Python)](https://medium.com/ibm-watson-data-lab/nodebooks-sharing-data-between-node-js-python-3a4acae27a02)
#     - [Part III (Visualization)](https://medium.com/ibm-watson-data-lab/nodebooks-visualising-data-the-node-js-way-d6cb7c9d6540)

# %%
# %%capture
# !pip install pixiedust;

# %%
# %%capture
# !pip install pixiedust_node;

# %%
import pixiedust_node
# Out:
# Pixiedust database opened successfully
#         <div style="margin:10px">
#             <a href="https://github.com/ibm-watson-data-lab/pixiedust" target="_new">
#                 <img src="https://github.com/ibm-watson-data-lab/pixiedust/raw/master/docs/_static/pd_icon32.png" style="float:left;margin-right:10px"/>
#             </a>
#             <span>Pixiedust version 1.1.15</span>
#         </div>
#             <div style="margin:10px">
#             <a href="https://github.com/ibm-cds-labs/pixiedust_node" target="_new">
#             <img src="https://github.com/ibm-cds-labs/pixiedust_node/raw/master/docs/_images/pdn_icon32.png" style="float:left;margin-right:10px"/>
#             </a>
#             <span>Pixiedust Node.js</span>
#             </div>
# pixiedust_node 0.2.5 started. Cells starting '%%node' may contain Node.js code.

# %% [markdown]
# # Introduction - Printing JS variables

# %%
# %%node
# console.log('test')
# Out:
# test

# %%
# %%node
# const x = 'xxx'
# const y = 'yyy'
# console.log(x,y)
# Out:
# xxx yyy

# %%
# %%node
# var date = new Date();
# print(date);
# Out:
# "2019-03-25T20:12:39.877Z"

# %%
# %%node
# var z = { a:1, b:2, c:3 };
# print(z);
# Out:
# {"a": 1, "b": 2, "c": 3}

# %% [markdown]
# # Using PixieDust display() to visualize data

# %%
# %%node
# var data = [];
# for (var i =0; i<1000; i++) {
#     var n = 2*Math.PI*i/360;
#     var obj = {
#         n:n, i:i,
#         sin: Math.sin(n), cos: Math.cos(n), tan: Math.tan(n)
#     };
#     data.push(obj);
# }
# display(data);
# Out:
# <style type="text/css">.pd_warning{display:none;}</style><div class="pd_warning"><em>Hey, there's something awesome here! To see it, open this notebook outside GitHub, in a viewer like Jupyter</em></div>
#         <div class="pd_save is-viewer-good" style="padding-right:10px;text-align: center;line-height:initial !important;font-size: xx-large;font-weight: 500;color: coral;">
#             test chart
#         </div>
#     <div id="chartFigure52b21080" class="pd_save is-viewer-good" style="overflow-x:auto">
#
#                     <script class="pd_save">
#                     function setChartScript() {
#                         if (!window.Bokeh) {
#                             setTimeout(setChartScript, 250)
#                         } else {
#                             var d = document.getElementById("pd-bkchartdiv-52b21080")
#                             if (d){
#                                 var el = document.createElement('div')
#                                 el.innerHTML = `
# <script type="text/javascript">
#   (function() {
#     var fn = function() {
#       Bokeh.safely(function() {
#         (function(root) {
#           function embed_document(root) {
#
#           var docs_json = '{"5166a4fa-7668-4171-b57d-1aa000ed2909":{"roots":{"references":[{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"render_mode":"css","right_units":"screen","top_units":"screen"},"id":"4ae8df1d-0cd6-462e-b98a-b0a139f521ad","type":"BoxAnnotation"},{"attributes":{"data_source":{"id":"4bd4d9b5-eced-477f-ac56-c64a9d083e99","type":"ColumnDataSource"},"glyph":{"id":"0d7b12f4-18e9-4790-b742-bd3cc4a4344c","type":"Line"},"hover_glyph":null,"muted_glyph":null,"nonselection_glyph":{"id":"ab2bb8f1-b6d3-42c3-afc4-d8097c008cd4","type":"Line"},"selection_glyph":null,"view":{"id":"1d2ef7c5-c8f6-49a0-b8c4-5af40b43249f","type":"CDSView"}},"id":"aa956c4e-532b-4b56-b2ee-bf6e2fa1b194","type":"GlyphRenderer"},{"attributes":{},"id":"04f3e75d-99c7-4bd9-a208-400fa2b717d1","type":"Selection"},{"attributes":{},"id":"0185bce7-b559-41f0-ba9c-575373e37a15","type":"LinearScale"},{"attributes":{"overlay":{"id":"4ae8df1d-0cd6-462e-b98a-b0a139f521ad","type":"BoxAnnotation"}},"id":"997735df-b8a9-4fa1-bca6-471858a848fc","type":"BoxZoomTool"},{"attributes":{"tools":[{"id":"b19b6719-bb57-43e4-9b51-e082e1e796b8","type":"PanTool"},{"id":"47213fa9-8def-4e43-b0bc-87ab45f446ba","type":"WheelZoomTool"},{"id":"997735df-b8a9-4fa1-bca6-471858a848fc","type":"BoxZoomTool"},{"id":"612c3d30-f9d9-463c-a1f6-f36cf1f8d2aa","type":"SaveTool"},{"id":"88f6f4c2-26de-49d8-a5cc-b921ca45a82c","type":"ResetTool"},{"id":"e831e701-acd0-474a-9a9a-37a86820d8e4","type":"HelpTool"},{"id":"204c3d42-f844-4819-94d4-6b6978f73851","type":"HoverTool"}]},"id":"957186f5-526a-4a85-b269-b0c43c860053","type":"ProxyToolbar"},{"attributes":{"line_alpha":0.1,"line_color":"#1f77b4","line_width":2,"x":{"field":"x"},"y":{"field":"y"}},"id":"ab2bb8f1-b6d3-42c3-afc4-d8097c008cd4","type":"Line"},{"attributes":{},"id":"c641be86-0c8c-4184-9090-103e0ccced87","type":"BasicTickFormatter"},{"attributes":{"toolbar":{"id":"957186f5-526a-4a85-b269-b0c43c860053","type":"ProxyToolbar"},"toolbar_location":"above"},"id":"8d60f960-d984-459c-ad72-990112247886","type":"ToolbarBox"},{"attributes":{},"id":"79488e4f-2648-4f32-a09e-aba52573ee48","type":"Selection"},{"attributes":{"dimension":1,"plot":{"id":"5f7377b9-3467-49d1-95d6-1bf9cb4395f5","subtype":"Figure","type":"Plot"},"ticker":{"id":"65cf48ce-fa7a-4833-96ca-d308510807f7","type":"BasicTicker"}},"id":"c9460431-b5e9-4cf5-8caa-0e34e3cd1484","type":"Grid"},{"attributes":{},"id":"e831e701-acd0-474a-9a9a-37a86820d8e4","type":"HelpTool"},{"attributes":{"items":[{"id":"e81cc586-7bc9-43bc-a664-386a5fd6cd82","type":"LegendItem"},{"id":"9fdd06de-8f4f-4101-9447-9389c8652674","type":"LegendItem"}],"location":"top_left","plot":{"id":"5f7377b9-3467-49d1-95d6-1bf9cb4395f5","subtype":"Figure","type":"Plot"}},"id":"b2860368-9f33-4c03-8d72-d4bd49133a42","type":"Legend"},{"attributes":{},"id":"65316d84-3610-4f21-80fc-026593b3023d","type":"UnionRenderers"},{"attributes":{},"id":"d5216f1a-dbcc-4f4c-96bf-460a6d8aad67","type":"UnionRenderers"},{"attributes":{"line_color":"#1f77b4","line_width":2,"x":{"field":"x"},"y":{"field":"y"}},"id":"e08bae81-d8af-4fc5-9bf5-ee600bd286f4","type":"Line"},{"attributes":{"callback":null},"id":"d9cfbce8-771e-4d42-a8d3-b62887060971","type":"DataRange1d"},{"attributes":{"callback":null,"renderers":"auto","tooltips":[["n","@x"],["cos,sin","@y{0.00}"],["x","$x"],["y","$y"]]},"id":"204c3d42-f844-4819-94d4-6b6978f73851","type":"HoverTool"},{"attributes":{"axis_label":"cos,sin","formatter":{"id":"c641be86-0c8c-4184-9090-103e0ccced87","type":"BasicTickFormatter"},"plot":{"id":"5f7377b9-3467-49d1-95d6-1bf9cb4395f5","subtype":"Figure","type":"Plot"},"ticker":{"id":"65cf48ce-fa7a-4833-96ca-d308510807f7","type":"BasicTicker"}},"id":"c8a137a7-06f3-442d-8e24-64669cbd7b82","type":"LinearAxis"},{"attributes":{"callback":null,"data":{"x":[0.052359877559829 ...

# %% [markdown]
# # Adding NPM modules
# * npm call is from a Python cell.
# * once install, you can require the module in your JS code.
# * let's try making HTTP calls to an external API using the npm __request__ module.

# %%
npm.install('request')
# Out:
# /home/bjpcjp/.nvm/versions/node/v10.6.0/bin/npm install -s request
# + request@2.88.0
# updated 1 package and audited 287 packages in 4.227s
# found 0 vulnerabilities

# %% [markdown]
# * HTTP request = an async action; the request library uses a __callback__ once done. Use __print__ to render inside the callback.
# * in this case request the current position of the ISS (International Space Station).

# %%
# %%node
# var request = require('request');
# var r = {
#     method:'GET',
#     url: 'http://api.open-notify.org/iss-now.json',
#     json: true
# };
# request(r, function(err, req, body) {
#     print(body);
# });
# Out:
# ... ... ... ...
# ... ...
# {"timestamp": 1553545586, "iss_position": {"latitude": "-22.1082", "longitude": "-92.8806"}, "message": "success"}

# %% [markdown]
# * Reorganizing code into functions for reuse in another cell:

# %%
# %%node
# var request = require('request');
# var getPosition = function(callback) {
#     var r = {
#         method:'GET',
#         url: 'http://api.open-notify.org/iss-now.json',
#         json: true
#     };
#     request(r, function(err, req, body) {
#         var obj = null;
#         if (!err) {
#             obj = body.iss_position
#             obj.latitude = parseFloat(obj.latitude);
#             obj.longitude = parseFloat(obj.longitude);
#             obj.time = new Date().getTime();
#         }
#         callback(err, obj);
#     });
# };
# Out:
# ... ..... ..... ..... ..... ... ..... ..... ....... ....... ....... ....... ....... ..... ..... ...

# %%
# %%node
# getPosition(function(err, data) {
#     print(data);
# });
# Out:
# ... ...
# {"latitude": -21.2644, "longitude": -92.1393, "time": 1553545605014}

# %% [markdown]
# # Promises
#
# * Install the NPM _request-promise_ module.
# * Refactor the function a bit.
# * Call it using a Promises style.

# %% [markdown]
#     npm.install(('request','request-promise'))

# %%
# %%node
# var request = require('request-promise');
# var getPosition = function(callback) {
#     var r = {
#         method:'GET',
#         url: 'http://api.open-notify.org/iss-now.json',
#         json: true
#     };
#     return request(r).then(function(body) {
#         var obj = null;
#         obj = body.iss_position
#         obj.latitude = parseFloat(obj.latitude);
#         obj.longitude = parseFloat(obj.longitude);
#         obj.time = new Date().getTime();
#         return obj;
#     });
# };
# Out:
# ... ..... ..... ..... ..... ... ..... ..... ..... ..... ..... ..... ..... ...

# %%
# %%node
# getPosition().then(function(data) {
#   print(data);
# });
# Out:
# ... ...
# {"latitude": -19.1992, "longitude": -90.3768, "time": 1553545647616}

# %%
# %%node
# getPosition().then(print);
# Out:
# {"latitude": -18.9792, "longitude": -90.193, "time": 1553545651674}

# %% [markdown]
# # Sharing data between NodeJS & Python cells
#
# Example:
# Waveform time series data, stored in variable _wave_.

# %%
# %%node
# var wave = [];
# for (var i = 0; i < 1000; i++) {
#     var xx = 2*Math.PI * i/ 360;
#     var obj = {
#       xx: xx,
#       i: i,
#       sin: Math.sin(xx),
#       cos: Math.cos(xx),
#       tan: Math.tan(xx)
#     };
#     wave.push(obj);
# }
# Out:
# ... ... ..... ..... ..... ..... ..... ..... ... ...

# %% [markdown]
#     print(wave); // outputs data as JSON
#     display(wave); // sends data to PixieDust visualization engine
#     store(wave, w); // copies JS data to a Python variable

# %%
# %%node
# store(wave,'w');
# Out:
# !!! Warning: store is now deprecated - Node.js global variables are automatically propagated to Python !!!

# %%
print(w.count())       #count of dataframe
print(w['sin'].max())  # max value of sin wave
print(w['sin'].min())  # min value of sin wave
print(w['tan'].mean()) # avg value of tan wave
# Out:
# cos    1000
# i      1000
# sin    1000
# tan    1000
# xx     1000
# dtype: int64
# 1.0
# -1.0
# 26897141197967.586

# %% [markdown]
# # Accessing a Cloudant database

# %%
npm.install('cloudant-quickstart')
# Out:
# /home/bjpcjp/.nvm/versions/node/v10.6.0/bin/npm install -s cloudant-quickstart
# + cloudant-quickstart@1.25.5
# updated 1 package and audited 287 packages in 3.092s
# found 0 vulnerabilities

# %%
# %%node
# // create connection
# var cloudantqs = require('cloudant-quickstart');
# var cities = cloudantqs('https://reader.cloudant.com/cities');

# %%
# %%node
# // --------------------------------------------------------------
# // explore the cities object.
# // if you know document IDs, you can retrieve them individually.
# // --------------------------------------------------------------
#
# cities.get('2636749').then(print);
# Out:
# {"_id": "2636749", "name": "Stowmarket", "latitude": 52.18893, "longitude": 0.99774, "country": "GB", "population": 15394, "timezone": "Europe/London"}

# %%
# %%node
# // --------------------------------------------------------------
# // grabbing cities data in bulk:
# // --------------------------------------------------------------
#
# cities.get(['4562407','2636749','3530597']).then(print);
# Out:
# [{"_id": "4562407", "name": "York", "latitude": 39.9626, "longitude": -76.72774, "country": "US", "population": 43718, "timezone": "America/New_York"}, {"_id": "2636749", "name": "Stowmarket", "latitude": 52.18893, "longitude": 0.99774, "country": "GB", "population": 15394, "timezone": "Europe/London"}, {"_id": "3530597", "name": "Mexico City", "latitude": 19.42847, "longitude": -99.12766, "country": "MX", "population": 12294193, "timezone": "America/Mexico_City"}]

# %%
# %%node
# // --------------------------------------------------------------
# // example of Cloudant query function:
# // --------------------------------------------------------------
#
# cities.query({country:'GB', latitude: { "$gt": 54}}).then(display);
# Out:
# <style type="text/css">.pd_warning{display:none;}</style><div class="pd_warning"><em>Hey, there's something awesome here! To see it, open this notebook outside GitHub, in a viewer like Jupyter</em></div>
#         <div class="pd_save is-viewer-good" style="padding-right:10px;text-align: center;line-height:initial !important;font-size: xx-large;font-weight: 500;color: coral;">
#
#         </div>
#     <div id="chartFigure23961d2a" class="pd_save is-viewer-good" style="overflow-x:auto">
#
#                 <div style="min-height: 50px;">
#                     <div style="color: red;position: absolute;bottom: 0;left: 0;">the JSON object must be str, bytes or bytearray, not 'int'</div>
#                 </div>
#
#         </div>

# %% [markdown]
# ### Aggregating data using cloudant-quickstart

# %%
# %%node
# cities.sum('population').then(print);
# Out:
# 2694222973

# %%
# %%node
# // return total population grouped by country:
# cities.sum('population','country').then(print)
# Out:
# (node:7945) UnhandledPromiseRejectionWarning: #<Object>
# (node:7945) UnhandledPromiseRejectionWarning: Unhandled promise rejection. This error originated either by throwing inside of an async function without a catch block, or by rejecting a promise which was not handled with .catch(). (rejection id: 1)
# (node:7945) [DEP0018] DeprecationWarning: Unhandled promise rejections are deprecated. In the future, promise rejections that are not handled will terminate the Node.js process with a non-zero exit code.

# %%
# %%node
# // moving data to Python using the store function:
# // NOTE: store is now deprecated, NodeJS global vars are auto-propagated to Python...
# pop25kcities = cities.all({limit:25000});

# %%
# accessing y in a python cell
pop25kcities['population'].sum()
# Out:
# 2694222973
